# %% [markdown]
# # 01. Dicionário de datasets

# %% [markdown]
# | Dataset               | Descrição                                                                                         |
# |---------------------------|-------------------------------------------------------------------------------------------------------|
# | clustered              | Dataset após aplicar o modelo de clusterização                                                        |
# | clean                  | Dataset tratado, deixando somente as colunas importantes, sem informações redundantes                 |
# | raw                    | Dataset inicial do projeto                                                                            |
